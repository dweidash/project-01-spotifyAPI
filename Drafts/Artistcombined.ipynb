# %%
# Dependencies and Setup
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
artistscombined = "artistcombined.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data
artistscombined = "artistcombined.csv"
artistdf = pd.read_csv(artistscombined)

# %%
artistnumber = 0
# Display the data table for preview
print(artistdf)
artistnumber = len(artistdf) # length of artists
# Out:
#     Unnamed: 0                    Artist  followers  popularity  \
# 0            0                Ed Sheeran   52850433          96
# 1            1              Roger Waters     835496          57
# 2            2             Kenny Chesney    2672559          75
# 3            3                Bruno Mars   22701560          88
# 4            4         Justin Timberlake    8373515          81
# 5            5           Imagine Dragons   22696963          90
# 6            6                 Sam Smith   10167854          90
# 7            7              Foo Fighters    6873440          80
# 8            8                Luke Bryan    4566106          78
# 9            9                    Eagles    3881640          78
# 10          10                        U2    5727123          80
# 11          11  Trans-Siberian Orchestra     185064          47
# 12          12            Helene Fischer     720600          66
# 13          13              Depeche Mode    2565181          75
# ...

# %%
# Clean column names and remove excess columns
artistdf = artistdf.drop('Unnamed: 0', 1) 
artistdf.rename(columns = {'2018':'Poll Ranking'}, inplace = True) 
artistdf.rename(columns = {'popularity':'Popularity Scale'}, inplace = True)
artistdf.rename(columns = {'Ticket_Sales': 'Ticket Sales'}, inplace = True)
artistdf.rename(columns = {'followers': 'Followers'}, inplace = True)
artistdf.rename(columns = {'genre': 'Genres'}, inplace = True)
artistdf[["Ticket Sales"]] = artistdf[["Ticket Sales"]].apply(pd.to_numeric)
# Display Dataframe
artistdf.head(10)
# Out:
#               Artist  Followers  Popularity Scale  \
# 0         Ed Sheeran   52850433                96
# 1       Roger Waters     835496                57
# 2      Kenny Chesney    2672559                75
# 3         Bruno Mars   22701560                88
# 4  Justin Timberlake    8373515                81
# 5    Imagine Dragons   22696963                90
# 6          Sam Smith   10167854                90
# 7       Foo Fighters    6873440                80
# 8         Luke Bryan    4566106                78
# 9             Eagles    3881640                78
#
#                                               Genres  Poll Ranking  \
# 0                                  ['pop', 'uk pop']             1
# 1  ['album rock', 'art rock', 'classic rock', 'pr...             5
# 2  ['contemporary country', 'country', 'country r...             6
# 3                                            ['pop']             7
# 4                               ['dance pop', 'pop']             9
# ...

# %%
colors = ('r')
plt.figure(figsize=(10, 10))
plt.scatter(artistdf["Followers"], artistdf["Ticket Sales"], c=colors, alpha=0.5, edgecolor="black") #Ticket Sales and Followers
plt.ylabel('Ticket Sales')
plt.yticks(np.arange(0, 5500000, step=100000))
plt.title('Ticket Sales vs Followers')
plt.xlabel('Followers')
plt.savefig('figure.png')
plt.show()

# %%
artistdf.dtypes
# Out:
# Artist              object
# Followers            int64
# Popularity Scale     int64
# Genres              object
# Poll Ranking         int64
# Ticket Sales         int64
# dtype: object
